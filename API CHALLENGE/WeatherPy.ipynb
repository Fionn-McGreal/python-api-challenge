# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
all_data = []
for i, city in enumerate (cities):
    city_url = url + "&q=" + city
    try :
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        # Append the City information into city_data list
        all_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    except : 
        print('city not found')
# Out:
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found
# city not found

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
all_data
# Out:
# [{'City': 'cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -6.74,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 9.86,
#   'Country': 'RU',
#   'Date': 1635812449},
#  {'City': 'jambi',
#   'Lat': -1.6,
#   'Lng': 103.6167,
#   'Max Temp': 75.88,
#   'Humidity': 94,
#   'Cloudiness': 89,
#   'Wind Speed': 1.77,
#   'Country': 'ID',
#   'Date': 1635812450},
#  {'City': 'owase',
#   'Lat': 34.0667,
#   'Lng': 136.2,
#   'Max Temp': 66.83,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 2.48,
#   'Country': 'JP',
#   'Date': 1635812450},
#  {'City': 'constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 51.73,
#   'Humidity': 89,
#   'Cloudiness': 96,
#   'Wind Speed': 9.22,
#   'Country': 'CL',
#   'Date': 1635812156},
#  {'City': 'hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 83.93,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': 1635812451},
#  {'City': 'tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 26.76,
#   'Humidity': 72,
#   'Cloudiness': 58,
#   'Wind Speed': 5.17,
#   'Country': 'GL',
#   'Date': 1635812452},
#  {'City': 'puerto escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 83.23,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'MX',
#   'Date': 1635812452},
#  {'City': 'tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 4.98,
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 7.65,
#   'Country': 'RU',
#   'Date': 1635812453},
#  {'City': 'sao filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 79.84,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 2.19,
#   'Country': 'CV',
#   'Date': 1635812453},
#  {'City': 'rabo de peixe',
#   'Lat': 37.8,
#   'Lng': -25.5833,
#   'Max Temp': 73.27,
#   'Humidity': 91,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'PT',
#   'Date': 1635812454},
#  {'City': 'praia da vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 73.65,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 6.35,
#   'Country': 'PT',
#   'Date': 1635812454},
#  {'City': 'kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 82.11,
#   'Humidity': 70,
#   'Cloudiness': 10,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': 1635812455},
#  {'City': 'cape town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 56.88,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 3,
#   'Country': 'ZA',
#   'Date': 1635812297},
#  {'City': 'ketchikan',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 48.67,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1635812456},
#  {'City': 'abohar',
#   'Lat': 30.15,
#   'Lng': 74.1833,
#   'Max Temp': 66.24,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Country': 'IN',
#   'Date': 1635812456},
#  {'City': 'severobaykalsk',
#   'Lat': 55.65,
#   'Lng': 109.3167,
#   'Max Temp': 21.99,
#   'Humidity': 78,
#   'Cloudiness': 58,
#   'Wind Speed': 9.8,
#   'Country': 'RU',
#   'Date': 1635812457},
#  {'City': 'port alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 61.41,
#   'Humidity': 62,
#   'Cloudiness': 62,
#   'Wind Speed': 27.63,
#   'Country': 'ZA',
#   'Date': 1635812457},
#  {'City': 'yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 33.42,
#   'Humidity': 98,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Date': 1635812442},
#  {'City': 'east london',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 63.01,
#   'Humidity': 58,
#   'Cloudiness': 70,
#   'Wind Speed': 19.1,
#   'Country': 'ZA',
#   'Date': 1635812457},
#  {'City': 'georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 78.73,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 1.01,
#   'Country': 'MY',
#   'Date': 1635812458},
#  {'City': 'kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 37.76,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 13.98,
#   'Country': 'US',
#   'Date': 1635812458},
#  {'City': 'ribeira grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 70.5,
#   'Humidity': 87,
#   'Cloudiness': 88,
#   'Wind Speed': 13.56,
#   'Country': 'PT',
#   'Date': 1635812459},
#  {'City': 'shingu',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Max Temp': 67.19,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 2.33,
#   'Country': 'JP',
#   'Date': 1635812459},
#  {'City': 'kemijarvi',
#   'Lat': 66.7131,
#   'Lng': 27.4306,
#   'Max Temp': 37.72,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 8.46,
#   'Country': 'FI',
#   'Date': 1635812460},
#  {'City': 'vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 37.83,
#   'Humidity': 65,
#   'Cloudiness': 63,
#   'Wind Speed': 26.31,
#   'Country': 'IS',
#   'Date': 1635812460},
#  {'City': 'barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 17.62,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': 1635812461},
#  {'City': 'souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 71.98,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'MU',
#   'Date': 1635812461},
#  {'City': 'busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 60.04,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 13.42,
#   'Country': 'AU',
#   'Date': 1635812462},
#  {'City': 'chato',
#   'Lat': -2.6378,
#   'Lng': 31.7669,
#   'Max Temp': 66.6,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 5.59,
#   'Country': 'TZ',
#   'Date': 1635812463},
#  {'City': 'butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.38,
#   'Humidity': 72,
#   'Cloudiness': 25,
#   'Wind Speed': 12.28,
#   'Country': 'KI',
#   'Date': 1635812463},
#  {'City': 'winslow',
#   'Lat': 35.0242,
#   'Lng': -110.6974,
#   'Max Temp': 69.98,
#   'Humidity': 29,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': 1635812464},
#  {'City': 'sinnamary',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 79.65,
#   'Humidity': 81,
#   'Cloudiness': 58,
#   'Wind Speed': 8.68,
#   'Country': 'GF',
#   'Date': 1635812464},
#  {'City': 'kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 58.89,
#   'Humidity': 81,
#   'Cloudiness': 29,
#   'Wind Speed': 21.85,
#   'Country': 'ZA',
#   'Date': 1635812465},
#  {'City': 'camopi',
#   'Lat': 3.1655,
#   'Lng': -52.3158,
#   'Max Temp': 73.65,
#   'Humidity': 98,
#   'Cloudiness': 89,
#   'Wind Speed': 2.82,
#   'Country': 'GF',
#   'Date': 1635812465},
#  {'City': 'puerto ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 69.15,
#   'Humidity': 86,
#   'Cloudiness': 70,
#   'Wind Speed': 7.65,
#   'Country': 'EC',
#   'Date': 1635812465},
#  {'City': 'saint-philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 71.15,
#   'Humidity': 81,
#   'Cloudiness': 38,
#   'Wind Speed': 10.98,
#   'Country': 'RE',
#   'Date': 1635812467},
#  {'City': 'saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -6.99,
#   'Humidity': 100,
#   'Cloudiness': 99,
#   'Wind Speed': 1.54,
#   'Country': 'RU',
#   'Date': 1635812467},
#  {'City': 'mahibadhoo',
#   'Lat': 3.7833,
#   'Lng': 72.9667,
#   'Max Temp': 81.99,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 15.46,
#   'Country': 'MV',
#   'Date': 1635812467},
#  {'City': 'lima',
#   'Lat': -12.0432,
#   'Lng': -77.0282,
#   'Max Temp': 64.9,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'PE',
#   'Date': 1635812468},
#  {'City': 'provins',
#   'Lat': 48.5833,
#   'Lng': 3.1667,
#   'Max Temp': 47.12,
#   'Humidity': 88,
#   'Cloudiness': 98,
#   'Wind Speed': 9.19,
#   'Country': 'FR',
#   'Date': 1635812469},
#  {'City': 'dunhua',
#   'Lat': 43.3725,
#   'Lng': 128.2425,
#   'Max Temp': 39.15,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 0.45,
#   'Country': 'CN',
#   'Date': 1635812469},
#  {'City': 'bonavista',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 52.12,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 15.48,
#   'Country': 'CA',
#   'Date': 1635812469},
#  {'City': 'pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 2.98,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 12.37,
#   'Country': 'RU',
#   'Date': 1635812470},
#  {'City': 'hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.89,
#   'Humidity': 74,
#   'Cloudiness': 29,
#   'Wind Speed': 18.52,
#   'Country': 'MV',
#   'Date': 1635812470},
#  {'City': 'guangyuan',
#   'Lat': 32.442,
#   'Lng': 105.823,
#   'Max Temp': 52.07,
#   'Humidity': 91,
#   'Cloudiness': 44,
#   'Wind Speed': 3.31,
#   'Country': 'CN',
#   'Date': 1635812471},
#  {'City': 'anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': -10.7,
#   'Humidity': 77,
#   'Cloudiness': 81,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Date': 1635812471},
#  {'City': 'riyadh',
#   'Lat': 24.6877,
#   'Lng': 46.7219,
#   'Max Temp': 66.34,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 4.76,
#   'Country': 'SA',
#   'Date': 1635812472},
#  {'City': 'nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 38.23,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 11.03,
#   'Country': 'GL',
#   'Date': 1635812472},
#  {'City': 'andenes',
#   'Lat': 69.3143,
#   'Lng': 16.1194,
#   'Max Temp': 48.18,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'NO',
#   'Date': 1635812472},
#  {'City': 'iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 24.53,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 15.01,
#   'Country': 'CA',
#   'Date': 1635812473},
#  {'City': 'kimbe',
#   'Lat': -5.5502,
#   'Lng': 150.1429,
#   'Max Temp': 87.69,
#   'Humidity': 62,
#   'Cloudiness': 76,
#   'Wind Speed': 0.4,
#   'Country': 'PG',
#   'Date': 1635812473},
#  {'City': 'puri',
#   'Lat': 19.8,
#   'Lng': 85.85,
#   'Max Temp': 75.72,
#   'Humidity': 77,
#   'Cloudiness': 79,
#   'Wind Speed': 8.79,
#   'Country': 'IN',
#   'Date': 1635812474},
#  {'City': 'muzhi',
#   'Lat': 65.3667,
#   'Lng': 64.6667,
#   'Max Temp': 6.1,
#   'Humidity': 81,
#   'Cloudiness': 5,
#   'Wind Speed': 8.57,
#   'Country': 'RU',
#   'Date': 1635812474},
#  {'City': 'formosa',
#   'Lat': -26.1775,
#   'Lng': -58.1781,
#   'Max Temp': 80.58,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'AR',
#   'Date': 1635812466},
#  {'City': 'hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 53.91,
#   'Humidity': 68,
#   'Cloudiness': 29,
#   'Wind Speed': 9.6,
#   'Country': 'ZA',
#   'Date': 1635812475},
#  {'City': 'isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 76.59,
#   'Humidity': 57,
#   'Cloudiness': 62,
#   'Wind Speed': 14.65,
#   'Country': 'VU',
#   'Date': 1635812475},
#  {'City': 'mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 54.48,
#   'Humidity': 36,
#   'Cloudiness': 58,
#   'Wind Speed': 9.98,
#   'Country': 'NZ',
#   'Date': 1635812476},
#  {'City': 'batagay-alyta',
#   'Lat': 67.8006,
#   'Lng': 130.4114,
#   'Max Temp': -14.6,
#   'Humidity': 87,
#   'Cloudiness': 48,
#   'Wind Speed': 6.04,
#   'Country': 'RU',
#   'Date': 1635812476},
#  {'City': 'vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 80.76,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'TO',
#   'Date': 1635812477},
#  {'City': 'punta arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 48.31,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'CL',
#   'Date': 1635812309},
#  {'City': 'erenhot',
#   'Lat': 43.6475,
#   'Lng': 111.9767,
#   'Max Temp': 39.74,
#   'Humidity': 52,
#   'Cloudiness': 33,
#   'Wind Speed': 16.58,
#   'Country': 'CN',
#   'Date': 1635812477},
#  {'City': 'rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 72.57,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 11.16,
#   'Country': 'PF',
#   'Date': 1635812478},
#  {'City': 'bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 54.81,
#   'Humidity': 58,
#   'Cloudiness': 64,
#   'Wind Speed': 19.57,
#   'Country': 'NZ',
#   'Date': 1635812478},
#  {'City': 'tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 24.8,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': 1635812479},
#  {'City': 'lakes entrance',
#   'Lat': -37.8811,
#   'Lng': 147.981,
#   'Max Temp': 72.16,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 7.58,
#   'Country': 'AU',
#   'Date': 1635812479},
#  {'City': 'dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 4.86,
#   'Humidity': 94,
#   'Cloudiness': 11,
#   'Wind Speed': 8.88,
#   'Country': 'RU',
#   'Date': 1635812480},
#  {'City': 'narasannapeta',
#   'Lat': 18.4167,
#   'Lng': 84.05,
#   'Max Temp': 73.81,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 6.64,
#   'Country': 'IN',
#   'Date': 1635812481},
#  {'City': 'taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 81.36,
#   'Humidity': 19,
#   'Cloudiness': 40,
#   'Wind Speed': 10.96,
#   'Country': 'ML',
#   'Date': 1635812481},
#  {'City': 'arraial do cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 71.46,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'BR',
#   'Date': 1635812481},
#  {'City': 'morada nova',
#   'Lat': -5.1067,
#   'Lng': -38.3725,
#   'Max Temp': 79.95,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 8.1,
#   'Country': 'BR',
#   'Date': 1635812482},
#  {'City': 'beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 67.39,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 5.23,
#   'Country': 'MG',
#   'Date': 1635812482},
#  {'City': 'naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 70.72,
#   'Humidity': 63,
#   'Cloudiness': 13,
#   'Wind Speed': 14.67,
#   'Country': 'JP',
#   'Date': 1635812483},
#  {'City': 'chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 64.87,
#   'Humidity': 95,
#   'Cloudiness': 89,
#   'Wind Speed': 8.79,
#   'Country': 'UY',
#   'Date': 1635812483},
#  {'City': 'qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 9.19,
#   'Humidity': 66,
#   'Cloudiness': 11,
#   'Wind Speed': 7.47,
#   'Country': 'GL',
#   'Date': 1635812484},
#  {'City': 'ambanja',
#   'Lat': -13.6833,
#   'Lng': 48.45,
#   'Max Temp': 74.79,
#   'Humidity': 90,
#   'Cloudiness': 87,
#   'Wind Speed': 2.55,
#   'Country': 'MG',
#   'Date': 1635812484},
#  {'City': 'doha',
#   'Lat': 25.2867,
#   'Lng': 51.5333,
#   'Max Temp': 78.78,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'QA',
#   'Date': 1635812485},
#  {'City': 'lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 50.74,
#   'Humidity': 86,
#   'Cloudiness': 12,
#   'Wind Speed': 5.53,
#   'Country': 'CL',
#   'Date': 1635812485},
#  {'City': 'norsup',
#   'Lat': -16.0667,
#   'Lng': 167.3833,
#   'Max Temp': 80.58,
#   'Humidity': 67,
#   'Cloudiness': 45,
#   'Wind Speed': 15.12,
#   'Country': 'VU',
#   'Date': 1635812485},
#  {'City': 'hammond',
#   'Lat': 41.5834,
#   'Lng': -87.5,
#   'Max Temp': 44.98,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': 1635812486},
#  {'City': 'albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 45.52,
#   'Humidity': 70,
#   'Cloudiness': 55,
#   'Wind Speed': 4.68,
#   'Country': 'US',
#   'Date': 1635812487},
#  {'City': 'ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 51.46,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AR',
#   'Date': 1635812487},
#  {'City': 'russell',
#   'Lat': 32.3502,
#   'Lng': -85.1999,
#   'Max Temp': 60.03,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1635812488},
#  {'City': 'taicheng',
#   'Lat': 38.731,
#   'Lng': 113.228,
#   'Max Temp': 40.82,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 4.56,
#   'Country': 'CN',
#   'Date': 1635812488},
#  {'City': 'dickinson',
#   'Lat': 29.4608,
#   'Lng': -95.0513,
#   'Max Temp': 73.62,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': 1635812489},
#  {'City': 'hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 78.26,
#   'Humidity': 86,
#   'Cloudiness': 97,
#   'Wind Speed': 8.14,
#   'Country': 'LK',
#   'Date': 1635812489},
#  {'City': 'bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 52.92,
#   'Humidity': 87,
#   'Cloudiness': 32,
#   'Wind Speed': 10.36,
#   'Country': 'ZA',
#   'Date': 1635812489},
#  {'City': 'richards bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 70.09,
#   'Humidity': 82,
#   'Cloudiness': 15,
#   'Wind Speed': 7.36,
#   'Country': 'ZA',
#   'Date': 1635812490},
#  {'City': 'lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 69.39,
#   'Humidity': 86,
#   'Cloudiness': 89,
#   'Wind Speed': 4.27,
#   'Country': 'PT',
#   'Date': 1635812490},
#  {'City': 'paracale',
#   'Lat': 14.2804,
#   'Lng': 122.7881,
#   'Max Temp': 80.89,
#   'Humidity': 82,
#   'Cloudiness': 71,
#   'Wind Speed': 13.38,
#   'Country': 'PH',
#   'Date': 1635812491},
#  {'City': 'hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 69.03,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 4,
#   'Country': 'AU',
#   'Date': 1635812419},
#  {'City': 'panjab',
#   'Lat': 34.388,
#   'Lng': 67.0233,
#   'Max Temp': 23.92,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 3.04,
#   'Country': 'AF',
#   'Date': 1635812492},
#  {'City': 'campo grande',
#   'Lat': -20.4428,
#   'Lng': -54.6464,
#   'Max Temp': 78.35,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'BR',
#   'Date': 1635812492},
#  {'City': 'olinda',
#   'Lat': -8.0089,
#   'Lng': -34.8553,
#   'Max Temp': 82.13,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'BR',
#   'Date': 1635812428},
#  {'City': 'evensk',
#   'Lat': 61.95,
#   'Lng': 159.2333,
#   'Max Temp': -1.5,
#   'Humidity': 80,
#   'Cloudiness': 16,
#   'Wind Speed': 4.59,
#   'Country': 'RU',
#   'Date': 1635812493},
#  {'City': 'shimoda',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 64.76,
#   'Humidity': 76,
#   'Cloudiness': 99,
#   'Wind Speed': 8.52,
#   'Country': 'JP',
#   'Date': 1635812493},
#  {'City': 'neftekamsk',
#   'Lat': 56.092,
#   'Lng': 54.2703,
#   'Max Temp': 40.41,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 8.81,
#   'Country': 'RU',
#   'Date': 1635812494},
#  {'City': 'evanston',
#   'Lat': 42.0411,
#   'Lng': -87.6901,
#   'Max Temp': 44.71,
#   'Humidity': 56,
#   'Cloudiness': 75,
#   'Wind Speed': 5.99,
#   'Country': 'US',
#   'Date': 1635812252},
#  {'City': 'luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 57.88,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 17.49,
#   'Country': 'NA',
#   'Date': 1635812494},
#  {'City': 'san policarpo',
#   'Lat': 12.1791,
#   'Lng': 125.5072,
#   'Max Temp': 81.18,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 14.12,
#   'Country': 'PH',
#   'Date': 1635812495},
#  {'City': 'palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 47.62,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': 1635812495},
#  {'City': 'saint george',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 72.63,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': 1635812482},
#  {'City': 'yagodnoye',
#   'Lat': 62.55,
#   'Lng': 149.6667,
#   'Max Temp': -9.89,
#   'Humidity': 85,
#   'Cloudiness': 26,
#   'Wind Speed': 3.22,
#   'Country': 'RU',
#   'Date': 1635812496},
#  {'City': 'mecca',
#   'Lat': 21.4267,
#   'Lng': 39.8261,
#   'Max Temp': 79.56,
#   'Humidity': 69,
#   'Cloudiness': 19,
#   'Wind Speed': 2.04,
#   'Country': 'SA',
#   'Date': 1635812461},
#  {'City': 'thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 28.56,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Date': 1635812497},
#  {'City': 'kroya',
#   'Lat': -7.6331,
#   'Lng': 109.2461,
#   'Max Temp': 78.82,
#   'Humidity': 84,
#   'Cloudiness': 98,
#   'Wind Speed': 1.66,
#   'Country': 'ID',
#   'Date': 1635812395},
#  {'City': 'aberdeen',
#   'Lat': 57.1437,
#   'Lng': -2.0981,
#   'Max Temp': 47.82,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'GB',
#   'Date': 1635812497},
#  {'City': 'sakakah',
#   'Lat': 29.9697,
#   'Lng': 40.2064,
#   'Max Temp': 72.97,
#   'Humidity': 34,
#   'Cloudiness': 4,
#   'Wind Speed': 6.24,
#   'Country': 'SA',
#   'Date': 1635812498},
#  {'City': 'college',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 32.58,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': 1635812498},
#  {'City': 'quepos',
#   'Lat': 9.4236,
#   'Lng': -84.1652,
#   'Max Temp': 80.53,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 1.39,
#   'Country': 'CR',
#   'Date': 1635812499},
#  {'City': 'tallahassee',
#   'Lat': 30.4383,
#   'Lng': -84.2807,
#   'Max Temp': 64.24,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': 1635812259},
#  {'City': 'babstovo',
#   'Lat': 48.1167,
#   'Lng': 132.4833,
#   'Max Temp': 34.86,
#   'Humidity': 32,
#   'Cloudiness': 46,
#   'Wind Speed': 2.68,
#   'Country': 'RU',
#   'Date': 1635812499},
#  {'City': 'port-cartier',
#   'Lat': 50.0334,
#   'Lng': -66.8654,
#   'Max Temp': 43.75,
#   'Humidity': 73,
#   'Cloudiness': 85,
#   'Wind Speed': 17.78,
#   'Country': 'CA',
#   'Date': 1635812500},
#  {'City': 'pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 64.45,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'PE',
#   'Date': 1635812501},
#  {'City': 'faya',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 53.71,
#   'Humidity': 45,
#   'Cloudiness': 58,
#   'Wind Speed': 2.82,
#   'Country': 'SA',
#   'Date': 1635812501},
#  {'City': 'namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 64.81,
#   'Humidity': 82,
#   'Cloudiness': 12,
#   'Wind Speed': 4.83,
#   'Country': 'AO',
#   'Date': 1635812501},
#  {'City': 'narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 34.02,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 5.46,
#   'Country': 'GL',
#   'Date': 1635812502},
#  {'City': 'viseu',
#   'Lat': 40.661,
#   'Lng': -7.9097,
#   'Max Temp': 53.89,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 3.38,
#   'Country': 'PT',
#   'Date': 1635812320},
#  {'City': 'norman wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 24.84,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': 1635812503},
#  {'City': 'kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 85.26,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Date': 1635812503},
#  {'City': 'castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 58.19,
#   'Humidity': 97,
#   'Cloudiness': 34,
#   'Wind Speed': 6.8,
#   'Country': 'BR',
#   'Date': 1635812504},
#  {'City': 'hailey',
#   'Lat': 43.5196,
#   'Lng': -114.3153,
#   'Max Temp': 48.9,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1635812504},
#  {'City': 'mount gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 74.57,
#   'Humidity': 34,
#   'Cloudiness': 18,
#   'Wind Speed': 12.8,
#   'Country': 'AU',
#   'Date': 1635812505},
#  {'City': 'bima',
#   'Lat': -8.4667,
#   'Lng': 118.7167,
#   'Max Temp': 85.1,
#   'Humidity': 71,
#   'Cloudiness': 67,
#   'Wind Speed': 2.84,
#   'Country': 'ID',
#   'Date': 1635812505},
#  {'City': 'torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 53.28,
#   'Humidity': 96,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Country': 'CA',
#   'Date': 1635812506},
#  {'City': 'southbridge',
#   'Lat': 42.0751,
#   'Lng': -72.0334,
#   'Max Temp': 47.34,
#   'Humidity': 82,
#   'Cloudiness': 18,
#   'Wind Speed': 4.41,
#   'Country': 'US',
#   'Date': 1635812507},
#  {'City': 'carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 66.27,
#   'Humidity': 48,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'AU',
#   'Date': 1635812507},
#  {'City': 'jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 44.33,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': 1635812507},
#  {'City': 'provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 21.31,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 22.37,
#   'Country': 'RU',
#   'Date': 1635812508},
#  {'City': 'sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 78.89,
#   'Humidity': 50,
#   'Cloudiness': 2,
#   'Wind Speed': 3.71,
#   'Country': 'OM',
#   'Date': 1635812508},
#  {'City': 'buloh kasap',
#   'Lat': 2.5536,
#   'Lng': 102.764,
#   'Max Temp': 76.91,
#   'Humidity': 94,
#   'Cloudiness': 92,
#   'Wind Speed': 2.44,
#   'Country': 'MY',
#   'Date': 1635812509},
#  {'City': 'mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 71.89,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'MU',
#   'Date': 1635812509},
#  {'City': 'akureyri',
#   'Lat': 65.6835,
#   'Lng': -18.0878,
#   'Max Temp': 33.73,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 20.71,
#   'Country': 'IS',
#   'Date': 1635812510},
#  {'City': 'chimoio',
#   'Lat': -19.1164,
#   'Lng': 33.4833,
#   'Max Temp': 65.97,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 1.63,
#   'Country': 'MZ',
#   'Date': 1635812395},
#  {'City': 'eydhafushi',
#   'Lat': 5.1033,
#   'Lng': 73.0708,
#   'Max Temp': 80.6,
#   'Humidity': 79,
#   'Cloudiness': 92,
#   'Wind Speed': 9.8,
#   'Country': 'MV',
#   'Date': 1635812511},
#  {'City': 'chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -5.39,
#   'Humidity': 98,
#   'Cloudiness': 94,
#   'Wind Speed': 9.06,
#   'Country': 'RU',
#   'Date': 1635812511},
#  {'City': 'xapuri',
#   'Lat': -10.6517,
#   'Lng': -68.5044,
#   'Max Temp': 79.05,
#   'Humidity': 72,
#   'Cloudiness': 78,
#   'Wind Speed': 1.99,
#   'Country': 'BR',
#   'Date': 1635812512},
#  {'City': 'ponta do sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 70.72,
#   'Humidity': 73,
#   'Cloudiness': 73,
#   'Wind Speed': 2.77,
#   'Country': 'PT',
#   'Date': 1635812512},
#  {'City': 'henties bay',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 56.86,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 10.11,
#   'Country': 'NA',
#   'Date': 1635812512},
#  {'City': 'severo-kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 37.08,
#   'Humidity': 53,
#   'Cloudiness': 78,
#   'Wind Speed': 20.15,
#   'Country': 'RU',
#   'Date': 1635812513},
#  {'City': 'los llanos de aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 65.95,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'ES',
#   'Date': 1635812513},
#  {'City': 'sao domingos',
#   'Lat': -13.3983,
#   'Lng': -46.3183,
#   'Max Temp': 74.43,
#   'Humidity': 64,
#   'Cloudiness': 94,
#   'Wind Speed': 1.45,
#   'Country': 'BR',
#   'Date': 1635812514},
#  {'City': 'tucuman',
#   'Lat': -26.8241,
#   'Lng': -65.2226,
#   'Max Temp': 60.8,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'AR',
#   'Date': 1635812414},
#  {'City': 'kassala',
#   'Lat': 15.451,
#   'Lng': 36.4,
#   'Max Temp': 83.82,
#   'Humidity': 53,
#   'Cloudiness': 86,
#   'Wind Speed': 9.78,
#   'Country': 'SD',
#   'Date': 1635812514},
#  {'City': 'acapulco',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 82.22,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'MX',
#   'Date': 1635812398},
#  {'City': 'upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 23.94,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 11.97,
#   'Country': 'GL',
#   'Date': 1635812515},
#  {'City': 'kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 81.18,
#   'Humidity': 77,
#   'Cloudiness': 92,
#   'Wind Speed': 5.57,
#   'Country': 'IN',
#   'Date': 1635812516},
#  {'City': 'port hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 48.2,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Date': 1635812516},
#  {'City': 'teguise',
#   'Lat': 29.0605,
#   'Lng': -13.564,
#   'Max Temp': 64.62,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'ES',
#   'Date': 1635812516},
#  {'City': 'ust-nera',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': -4.72,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.44,
#   'Country': 'RU',
#   'Date': 1635812517},
#  {'City': 'obo',
#   'Lat': 5.3998,
#   'Lng': 26.4869,
#   'Max Temp': 67.44,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.27,
#   'Country': 'CF',
#   'Date': 1635812517},
#  {'City': 'saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 48.25,
#   'Humidity': 53,
#   'Cloudiness': 37,
#   'Wind Speed': 5.17,
#   'Country': 'ZA',
#   'Date': 1635812518},
#  {'City': 'katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 69.12,
#   'Humidity': 88,
#   'Cloudiness': 93,
#   'Wind Speed': 9.37,
#   'Country': 'JP',
#   'Date': 1635812518},
#  {'City': 'quimper',
#   'Lat': 48,
#   'Lng': -4.1,
#   'Max Temp': 48.76,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'FR',
#   'Date': 1635812519},
#  {'City': 'san cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 69.98,
#   'Humidity': 96,
#   'Cloudiness': 50,
#   'Wind Speed': 2.71,
#   'Country': 'VE',
#   'Date': 1635812519},
#  {'City': 'neftcala',
#   'Lat': 39.3742,
#   'Lng': 49.2472,
#   'Max Temp': 61.56,
#   'Humidity': 91,
#   'Cloudiness': 86,
#   'Wind Speed': 5.82,
#   'Country': 'AZ',
#   'Date': 1635812520},
#  {'City': 'hobyo',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 79.93,
#   'Humidity': 75,
#   'Cloudiness': 69,
#   'Wind Speed': 9.42,
#   'Country': 'SO',
#   'Date': 1635812520},
#  {'City': 'raymondville',
#   'Lat': 26.4815,
#   'Lng': -97.7831,
#   'Max Temp': 81.59,
#   'Humidity': 56,
#   'Cloudiness': 43,
#   'Wind Speed': 13.44,
#   'Country': 'US',
#   'Date': 1635812520},
#  {'City': 'edd',
#   'Lat': 13.9297,
#   'Lng': 41.6925,
#   'Max Temp': 84.96,
#   'Humidity': 48,
#   'Cloudiness': 55,
#   'Wind Speed': 12.26,
#   'Country': 'ER',
#   'Date': 1635812521},
#  {'City': 'mar del plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 57.09,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'AR',
#   'Date': 1635812502},
#  {'City': 'bud',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 44.69,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 6.89,
#   'Country': 'US',
#   'Date': 1635812522},
#  {'City': 'kibre mengist',
#   'Lat': 5.8833,
#   'Lng': 38.9833,
#   'Max Temp': 53.67,
#   'Humidity': 94,
#   'Cloudiness': 74,
#   'Wind Speed': 3.27,
#   'Country': 'ET',
#   'Date': 1635812522},
#  {'City': 'mandalgovi',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 27.05,
#   'Humidity': 45,
#   'Cloudiness': 14,
#   'Wind Speed': 10.78,
#   'Country': 'MN',
#   'Date': 1635812523},
#  {'City': 'ponta delgada',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 74.5,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'PT',
#   'Date': 1635812524},
#  {'City': 'kerrville',
#   'Lat': 30.0474,
#   'Lng': -99.1403,
#   'Max Temp': 71.82,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': 1635812253},
#  {'City': 'lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 68.77,
#   'Humidity': 75,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': 1635812524},
#  {'City': 'uglegorsk',
#   'Lat': 49.0833,
#   'Lng': 142.0333,
#   'Max Temp': 37.04,
#   'Humidity': 65,
#   'Cloudiness': 13,
#   'Wind Speed': 7.45,
#   'Country': 'RU',
#   'Date': 1635812525},
#  {'City': 'fare',
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp': 80.06,
#   'Humidity': 78,
#   'Cloudiness': 30,
#   'Wind Speed': 14.79,
#   'Country': 'PF',
#   'Date': 1635812526},
#  {'City': 'osoyoos',
#   'Lat': 49.0331,
#   'Lng': -119.4524,
#   'Max Temp': 47.34,
#   'Humidity': 67,
#   'Cloudiness': 50,
#   'Wind Speed': 0,
#   'Country': 'CA',
#   'Date': 1635812526},
#  {'City': 'kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 84,
#   'Humidity': 73,
#   'Cloudiness': 87,
#   'Wind Speed': 5.97,
#   'Country': 'PG',
#   'Date': 1635812527},
#  {'City': 'bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 51.49,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': 1635812527},
#  {'City': 'madimba',
#   'Lat': -10.4,
#   'Lng': 40.3333,
#   'Max Temp': 76.75,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 8.23,
#   'Country': 'TZ',
#   'Date': 1635812527},
#  {'City': 'puerto palomas',
#   'Lat': 31.7667,
#   'Lng': -107.6167,
#   'Max Temp': 74.53,
#   'Humidity': 17,
#   'Cloudiness': 48,
#   'Wind Speed': 10.49,
#   'Country': 'MX',
#   'Date': 1635812528},
#  {'City': 'dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 80.85,
#   'Humidity': 82,
#   'Cloudiness': 84,
#   'Wind Speed': 10.51,
#   'Country': 'PH',
#   'Date': 1635812528},
#  {'City': 'at-bashi',
#   'Lat': 41.1702,
#   'Lng': 75.8106,
#   'Max Temp': 21.51,
#   'Humidity': 65,
#   'Cloudiness': 4,
#   'Wind Speed': 2.98,
#   'Country': 'KG',
#   'Date': 1635812529},
#  {'City': 'akyab',
#   'Lat': 20.15,
#   'Lng': 92.9,
#   'Max Temp': 76.12,
#   'Humidity': 86,
#   'Cloudiness': 66,
#   'Wind Speed': 4.94,
#   'Country': 'MM',
#   'Date': 1635812529},
#  {'City': 'marsh harbour',
#   'Lat': 26.5412,
#   'Lng': -77.0636,
#   'Max Temp': 76.95,
#   'Humidity': 64,
#   'Cloudiness': 85,
#   'Wind Speed': 14.25,
#   'Country': 'BS',
#   'Date': 1635812529},
#  {'City': 'sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 80.49,
#   'Humidity': 75,
#   'Cloudiness': 22,
#   'Wind Speed': 19.13,
#   'Country': 'VU',
#   'Date': 1635812530},
#  {'City': 'ugoofaaru',
#   'Lat': 5.6667,
#   'Lng': 73,
#   'Max Temp': 79.72,
#   'Humidity': 80,
#   'Cloudiness': 97,
#   'Wind Speed': 4.05,
#   'Country': 'MV',
#   'Date': 1635812530},
#  {'City': 'wodonga',
#   'Lat': -36.1167,
#   'Lng': 146.8833,
#   'Max Temp': 75.06,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Country': 'AU',
#   'Date': 1635812531},
#  {'City': 'midland',
#   'Lat': 31.9974,
#   'Lng': -102.0779,
#   'Max Temp': 70.68,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': 1635812493},
#  {'City': 'saint-francois',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 48.47,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'FR',
#   'Date': 1635812532},
#  {'City': 'hovd',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 28.63,
#   'Humidity': 41,
#   'Cloudiness': 75,
#   'Wind Speed': 9.31,
#   'Country': 'MN',
#   'Date': 1635812532},
#  {'City': 'petropavlovsk-kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 30.79,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 13.42,
#   'Country': 'RU',
#   'Date': 1635812423},
#  {'City': 'pyaozerskiy',
#   'Lat': 65.8333,
#   'Lng': 31.1667,
#   'Max Temp': 39.04,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 7.05,
#   'Country': 'RU',
#   'Date': 1635812533},
#  {'City': 'temiscaming',
#   'Lat': 46.7212,
#   'Lng': -79.0971,
#   'Max Temp': 43.68,
#   'Humidity': 70,
#   'Cloudiness': 35,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': 1635812494},
#  {'City': 'mugango',
#   'Lat': -1.6833,
#   'Lng': 33.7,
#   'Max Temp': 72.07,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 5.88,
#   'Country': 'TZ',
#   'Date': 1635812534},
#  {'City': 'kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 55.94,
#   'Humidity': 39,
#   'Cloudiness': 44,
#   'Wind Speed': 11.52,
#   'Country': 'NZ',
#   'Date': 1635812534},
#  {'City': 'asilah',
#   'Lat': 35.465,
#   'Lng': -6.0348,
#   'Max Temp': 71.46,
#   'Humidity': 95,
#   'Cloudiness': 20,
#   'Wind Speed': 8.5,
#   'Country': 'MA',
#   'Date': 1635812534},
#  {'City': 'pingdu',
#   'Lat': 36.7844,
#   'Lng': 119.9464,
#   'Max Temp': 45.84,
#   'Humidity': 64,
#   'Cloudiness': 99,
#   'Wind Speed': 2.55,
#   'Country': 'CN',
#   'Date': 1635812535},
#  {'City': 'komsomolets',
#   'Lat': 53.7453,
#   'Lng': 62.0708,
#   'Max Temp': 32.95,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 15.23,
#   'Country': 'KZ',
#   'Date': 1635812535},
#  {'City': 'padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 75.25,
#   'Humidity': 84,
#   'Cloudiness': 87,
#   'Wind Speed': 2.46,
#   'Country': 'ID',
#   'Date': 1635812536},
#  {'City': 'marienberg',
#   'Lat': 50.65,
#   'Lng': 13.1667,
#   'Max Temp': 43.72,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.42,
#   'Country': 'DE',
#   'Date': 1635812536},
#  {'City': 'ekibastuz',
#   'Lat': 51.6667,
#   'Lng': 75.3667,
#   'Max Temp': 40.1,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 13.06,
#   'Country': 'KZ',
#   'Date': 1635812431},
#  {'City': 'airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 72.64,
#   'Humidity': 53,
#   'Cloudiness': 79,
#   'Wind Speed': 2.46,
#   'Country': 'TL',
#   'Date': 1635812537},
#  {'City': 'tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 54.82,
#   'Humidity': 53,
#   'Cloudiness': 64,
#   'Wind Speed': 12.73,
#   'Country': 'NZ',
#   'Date': 1635812537},
#  {'City': 'faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 79.93,
#   'Humidity': 78,
#   'Cloudiness': 13,
#   'Wind Speed': 13.27,
#   'Country': 'PF',
#   'Date': 1635812538},
#  {'City': 'olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 34.47,
#   'Humidity': 68,
#   'Cloudiness': 98,
#   'Wind Speed': 23.33,
#   'Country': 'IS',
#   'Date': 1635812538},
#  {'City': 'samarai',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 83.7,
#   'Humidity': 73,
#   'Cloudiness': 76,
#   'Wind Speed': 13.65,
#   'Country': 'PG',
#   'Date': 1635812539},
#  {'City': 'qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 34.3,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 6.15,
#   'Country': 'GL',
#   'Date': 1635812540},
#  {'City': 'atyrau',
#   'Lat': 47.1167,
#   'Lng': 51.8833,
#   'Max Temp': 41.02,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Country': 'KZ',
#   'Date': 1635812540},
#  {'City': 'vostok',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 36.28,
#   'Humidity': 65,
#   'Cloudiness': 21,
#   'Wind Speed': 0.56,
#   'Country': 'RU',
#   'Date': 1635812540},
#  {'City': 'plettenberg bay',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 57.45,
#   'Humidity': 76,
#   'Cloudiness': 62,
#   'Wind Speed': 14.52,
#   'Country': 'ZA',
#   'Date': 1635812541},
#  {'City': 'moussoro',
#   'Lat': 13.6408,
#   'Lng': 16.4901,
#   'Max Temp': 87.8,
#   'Humidity': 18,
#   'Cloudiness': 72,
#   'Wind Speed': 10.38,
#   'Country': 'TD',
#   'Date': 1635812541},
#  {'City': 'te anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 54.07,
#   'Humidity': 48,
#   'Cloudiness': 16,
#   'Wind Speed': 5.59,
#   'Country': 'NZ',
#   'Date': 1635812542},
#  {'City': 'kerouane',
#   'Lat': 9.2667,
#   'Lng': -9.0167,
#   'Max Temp': 69.76,
#   'Humidity': 90,
#   'Cloudiness': 94,
#   'Wind Speed': 2.98,
#   'Country': 'GN',
#   'Date': 1635812542},
#  {'City': 'ndele',
#   'Lat': 8.4109,
#   'Lng': 20.6473,
#   'Max Temp': 70.97,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.2,
#   'Country': 'CF',
#   'Date': 1635812543},
#  {'City': 'mirante do paranapanema',
#   'Lat': -22.2919,
#   'Lng': -51.9064,
#   'Max Temp': 75.13,
#   'Humidity': 70,
#   'Cloudiness': 83,
#   'Wind Speed': 2.1,
#   'Country': 'BR',
#   'Date': 1635812543},
#  {'City': 'orchard homes',
#   'Lat': 46.8633,
#   'Lng': -114.0484,
#   'Max Temp': 44.92,
#   'Humidity': 52,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': 1635812543},
#  {'City': 'deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -12.37,
#   'Humidity': 92,
#   'Cloudiness': 34,
#   'Wind Speed': 4.99,
#   'Country': 'RU',
#   'Date': 1635812544},
#  {'City': 'buchanan',
#   'Lat': 5.8808,
#   'Lng': -10.0467,
#   'Max Temp': 76.96,
#   'Humidity': 84,
#   'Cloudiness': 96,
#   'Wind Speed': 4.14,
#   'Country': 'LR',
#   'Date': 1635812544},
#  {'City': 'talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -1.48,
#   'Humidity': 93,
#   'Cloudiness': 96,
#   'Wind Speed': 9.93,
#   'Country': 'RU',
#   'Date': 1635812545},
#  {'City': 'jacareacanga',
#   'Lat': -6.2222,
#   'Lng': -57.7528,
#   'Max Temp': 70.99,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.83,
#   'Country': 'BR',
#   'Date': 1635812545},
#  {'City': 'pedernales',
#   'Lat': 18.0384,
#   'Lng': -71.744,
#   'Max Temp': 80.01,
#   'Humidity': 75,
#   'Cloudiness': 17,
#   'Wind Speed': 4.59,
#   'Country': 'DO',
#   'Date': 1635812546},
#  {'City': 'moose factory',
#   'Lat': 51.2585,
#   'Lng': -80.6094,
#   'Max Temp': 33.8,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 19.57,
#   'Country': 'CA',
#   'Date': 1635812546},
#  {'City': 'saint-georges',
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp': 80.28,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'GD',
#   'Date': 1635812547},
#  {'City': 'zonguldak',
#   'Lat': 41.25,
#   'Lng': 31.8333,
#   'Max Temp': 47.66,
#   'Humidity': 94,
#   'Cloudiness': 26,
#   'Wind Speed': 2.89,
#   'Country': 'TR',
#   'Date': 1635812365},
#  {'City': 'nata',
#   'Lat': 8.3333,
#   'Lng': -80.5167,
#   'Max Temp': 74.3,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.41,
#   'Country': 'PA',
#   'Date': 1635812547},
#  {'City': 'new norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 68.67,
#   'Humidity': 41,
#   'Cloudiness': 49,
#   'Wind Speed': 4,
#   'Country': 'AU',
#   'Date': 1635812548},
#  {'City': 'prince rupert',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 58.69,
#   'Humidity': 40,
#   'Cloudiness': 2,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Date': 1635812548},
#  {'City': 'manaus',
#   'Lat': -3.1019,
#   'Lng': -60.025,
#   'Max Temp': 75.7,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'BR',
#   'Date': 1635812424},
#  {'City': 'shelburne',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 39.76,
#   'Humidity': 71,
#   'Cloudiness': 62,
#   'Wind Speed': 12.88,
#   'Country': 'CA',
#   'Date': 1635812549},
#  {'City': 'hualmay',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 64.4,
#   'Humidity': 84,
#   'Cloudiness': 23,
#   'Wind Speed': 9.4,
#   'Country': 'PE',
#   'Date': 1635812549},
#  {'City': 'constantine',
#   'Lat': 36.365,
#   'Lng': 6.6147,
#   'Max Temp': 62.01,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'DZ',
#   'Date': 1635812550},
#  {'City': 'hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 63.28,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.48,
#   'Country': 'JP',
#   'Date': 1635812550},
#  {'City': 'okha',
#   'Lat': 53.5739,
#   'Lng': 142.9478,
#   'Max Temp': 32.7,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 7.18,
#   'Country': 'RU',
#   'Date': 1635812551},
#  {'City': 'fortuna foothills',
#   'Lat': 32.6578,
#   'Lng': -114.4119,
#   'Max Temp': 86.22,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': 1635812551},
#  {'City': 'cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 68.56,
#   'Humidity': 90,
#   'Cloudiness': 40,
#   'Wind Speed': 19.24,
#   'Country': 'BR',
#   'Date': 1635812552},
#  {'City': 'hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 50.74,
#   'Humidity': 59,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': 1635812552},
#  {'City': 'belen',
#   'Lat': 36.4891,
#   'Lng': 36.2233,
#   'Max Temp': 55.54,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'TR',
#   'Date': 1635812552},
#  {'City': 'dingli',
#   'Lat': 35.8614,
#   'Lng': 14.3822,
#   'Max Temp': 69.96,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'MT',
#   'Date': 1635812553},
#  {'City': 'yicheng',
#   'Lat': 31.3705,
#   'Lng': 119.8703,
#   'Max Temp': 60.69,
#   'Humidity': 77,
#   'Cloudiness': 91,
#   'Wind Speed': 10.92,
#   'Country': 'CN',
#   'Date': 1635812553},
#  {'City': 'bambous virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 71.85,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'MU',
#   'Date': 1635812554},
#  {'City': 'rush',
#   'Lat': 53.5223,
#   'Lng': -6.0931,
#   'Max Temp': 43.88,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'IE',
#   'Date': 1635812555},
#  {'City': 'plouzane',
#   'Lat': 48.3833,
#   'Lng': -4.6167,
#   'Max Temp': 48.25,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'FR',
#   'Date': 1635812555},
#  {'City': 'avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 78.85,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Country': 'CK',
#   'Date': 1635812555},
#  {'City': 'asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 47.32,
#   'Humidity': 90,
#   'Cloudiness': 8,
#   'Wind Speed': 3.94,
#   'Country': 'RO',
#   'Date': 1635812556},
#  {'City': 'roald',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 53.74,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'NO',
#   'Date': 1635812556},
#  {'City': 'portalegre',
#   'Lat': 39.2938,
#   'Lng': -7.4312,
#   'Max Temp': 50.5,
#   'Humidity': 85,
#   'Cloudiness': 56,
#   'Wind Speed': 4.34,
#   'Country': 'PT',
#   'Date': 1635812334},
#  {'City': 'filadelfia',
#   'Lat': 39.9523,
#   'Lng': -75.1638,
#   'Max Temp': 52.32,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': 1635812336},
#  {'City': 'tinos',
#   'Lat': 37.5375,
#   'Lng': 25.1634,
#   'Max Temp': 61.56,
#   'Humidity': 69,
#   'Cloudiness': 65,
#   'Wind Speed': 5.59,
#   'Country': 'GR',
#   'Date': 1635812557},
#  {'City': 'winnemucca',
#   'Lat': 40.973,
#   'Lng': -117.7357,
#   'Max Temp': 57.25,
#   'Humidity': 58,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': 1635812558},
#  {'City': 'kiama',
#   'Lat': -34.6833,
#   'Lng': 150.8667,
#   'Max Temp': 76.37,
#   'Humidity': 65,
#   'Cloudiness': 5,
#   'Wind Speed': 7.47,
#   'Country': 'AU',
#   'Date': 1635812558},
#  {'City': 'belaya gora',
#   'Lat': 68.5333,
#   'Lng': 146.4167,
#   'Max Temp': 1.83,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.67,
#   'Country': 'RU',
#   'Date': 1635812558},
#  {'City': 'igurubi',
#   'Lat': -4,
#   'Lng': 33.7,
#   'Max Temp': 77.18,
#   'Humidity': 51,
#   'Cloudiness': 89,
#   'Wind Speed': 3.42,
#   'Country': 'TZ',
#   'Date': 1635812559},
#  {'City': 'atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.13,
#   'Humidity': 70,
#   'Cloudiness': 24,
#   'Wind Speed': 11.12,
#   'Country': 'PF',
#   'Date': 1635812559},
#  {'City': 'port elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 61.11,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 27.63,
#   'Country': 'ZA',
#   'Date': 1635812560},
#  {'City': 'husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 33.71,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 19.6,
#   'Country': 'IS',
#   'Date': 1635812560},
#  {'City': 'umm lajj',
#   'Lat': 25.0213,
#   'Lng': 37.2685,
#   'Max Temp': 83.73,
#   'Humidity': 56,
#   'Cloudiness': 86,
#   'Wind Speed': 6.35,
#   'Country': 'SA',
#   'Date': 1635812561},
#  {'City': 'vila',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 47.32,
#   'Humidity': 90,
#   'Cloudiness': 91,
#   'Wind Speed': 5.01,
#   'Country': 'PT',
#   'Date': 1635812561},
#  {'City': 'bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 76.78,
#   'Humidity': 73,
#   'Cloudiness': 50,
#   'Wind Speed': 9.8,
#   'Country': 'SO',
#   'Date': 1635812561},
#  {'City': 'cefalu',
#   'Lat': 38.0386,
#   'Lng': 14.0229,
#   'Max Temp': 71.55,
#   'Humidity': 74,
#   'Cloudiness': 94,
#   'Wind Speed': 25.01,
#   'Country': 'IT',
#   'Date': 1635812562},
#  {'City': 'kashi',
#   'Lat': 39.4547,
#   'Lng': 75.9797,
#   'Max Temp': 45.27,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Country': 'CN',
#   'Date': 1635812562},
#  {'City': 'carroll',
#   'Lat': 39.5501,
#   'Lng': -77.0164,
#   'Max Temp': 49.89,
#   'Humidity': 72,
#   'Cloudiness': 15,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': 1635812563},
#  {'City': 'sambava',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp': 73,
#   'Humidity': 91,
#   'Cloudiness': 6,
#   'Wind Speed': 3.29,
#   'Country': 'MG',
#   'Date': 1635812563},
#  {'City': 'makubetsu',
#   'Lat': 45.3714,
#   'Lng': 141.8211,
#   'Max Temp': 46.11,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'JP',
#   'Date': 1635812564},
#  {'City': 'manicore',
#   'Lat': -5.8092,
#   'Lng': -61.3003,
#   'Max Temp': 73.96,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.53,
#   'Country': 'BR',
#   'Date': 1635812564},
#  {'City': 'vila franca do campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 74.19,
#   'Humidity': 90,
#   'Cloudiness': 87,
#   'Wind Speed': 4.97,
#   'Country': 'PT',
#   'Date': 1635812565},
#  {'City': 'chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 31.78,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 16.73,
#   'Country': 'CA',
#   'Date': 1635812265},
#  {'City': 'hay river',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': 37.38,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Date': 1635812565},
#  {'City': 'cabra',
#   'Lat': 37.4725,
#   'Lng': -4.4421,
#   'Max Temp': 65.39,
#   'Humidity': 86,
#   'Cloudiness': 76,
#   'Wind Speed': 3.71,
#   'Country': 'ES',
#   'Date': 1635812566},
#  {'City': 'tete',
#   'Lat': -16.1564,
#   'Lng': 33.5867,
#   'Max Temp': 87.89,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'MZ',
#   'Date': 1635812566},
#  {'City': 'bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 75.81,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.68,
#   'Country': 'ID',
#   'Date': 1635812567},
#  {'City': 'vanavara',
#   'Lat': 60.34,
#   'Lng': 102.2797,
#   'Max Temp': 13.17,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 7.52,
#   'Country': 'RU',
#   'Date': 1635812567},
#  {'City': 'labuhan',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 81.9,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 6.78,
#   'Country': 'ID',
#   'Date': 1635812567},
#  {'City': 'nikolskoye',
#   'Lat': 59.7035,
# ...
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 26.67,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 20.71,
#   'Country': 'US',
#   'Date': 1635812477},
#  {'City': 'zaozerne',
#   'Lat': 45.1582,
#   'Lng': 33.2787,
#   'Max Temp': 56.95,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.6,
#   'Country': 'UA',
#   'Date': 1635812662},
#  {'City': 'chillicothe',
#   'Lat': 39.3331,
#   'Lng': -82.9824,
#   'Max Temp': 49.62,
#   'Humidity': 53,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': 1635812662},
#  {'City': 'mount isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 89.37,
#   'Humidity': 40,
#   'Cloudiness': 57,
#   'Wind Speed': 13.8,
#   'Country': 'AU',
#   'Date': 1635812662},
#  {'City': 'nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 45.03,
#   'Humidity': 68,
#   'Cloudiness': 99,
#   'Wind Speed': 17.85,
#   'Country': 'JP',
#   'Date': 1635812663},
#  {'City': 'iquitos',
#   'Lat': -3.7481,
#   'Lng': -73.2472,
#   'Max Temp': 80.64,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'PE',
#   'Date': 1635812663},
#  {'City': 'sterling',
#   'Lat': 39.0062,
#   'Lng': -77.4286,
#   'Max Temp': 52.27,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1635812597},
#  {'City': 'rassvet',
#   'Lat': 46.8333,
#   'Lng': 40.75,
#   'Max Temp': 49.69,
#   'Humidity': 94,
#   'Cloudiness': 82,
#   'Wind Speed': 12.17,
#   'Country': 'RU',
#   'Date': 1635812664},
#  {'City': 'yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 66.04,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'AU',
#   'Date': 1635812665},
#  {'City': 'wellington',
#   'Lat': -41.2866,
#   'Lng': 174.7756,
#   'Max Temp': 67.77,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 5.01,
#   'Country': 'NZ',
#   'Date': 1635812665},
#  {'City': 'takanosu',
#   'Lat': 40.2219,
#   'Lng': 140.3694,
#   'Max Temp': 62.82,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'JP',
#   'Date': 1635812665},
#  {'City': 'san jose',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 65.82,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': 1635812402},
#  {'City': 'coromandel',
#   'Lat': -18.4733,
#   'Lng': -47.2003,
#   'Max Temp': 64.85,
#   'Humidity': 93,
#   'Cloudiness': 19,
#   'Wind Speed': 2.28,
#   'Country': 'BR',
#   'Date': 1635812666},
#  {'City': 'leua',
#   'Lat': 48.2156,
#   'Lng': 18.6071,
#   'Max Temp': 51.49,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 15.32,
#   'Country': 'SK',
#   'Date': 1635812666},
#  {'City': 'dunedin',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 55.8,
#   'Humidity': 40,
#   'Cloudiness': 31,
#   'Wind Speed': 14,
#   'Country': 'NZ',
#   'Date': 1635812667},
#  {'City': 'baruun-urt',
#   'Lat': 46.6806,
#   'Lng': 113.2792,
#   'Max Temp': 33.51,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 12.5,
#   'Country': 'MN',
#   'Date': 1635812667},
#  {'City': 'bocana de paiwas',
#   'Lat': 12.7857,
#   'Lng': -85.1227,
#   'Max Temp': 73.47,
#   'Humidity': 93,
#   'Cloudiness': 92,
#   'Wind Speed': 8.46,
#   'Country': 'NI',
#   'Date': 1635812668},
#  {'City': 'nueva rosita',
#   'Lat': 27.95,
#   'Lng': -101.2167,
#   'Max Temp': 75.34,
#   'Humidity': 61,
#   'Cloudiness': 24,
#   'Wind Speed': 10.45,
#   'Country': 'MX',
#   'Date': 1635812668},
#  {'City': 'moquegua',
#   'Lat': -17.1956,
#   'Lng': -70.9353,
#   'Max Temp': 64.29,
#   'Humidity': 55,
#   'Cloudiness': 2,
#   'Wind Speed': 3.22,
#   'Country': 'PE',
#   'Date': 1635812668},
#  {'City': 'george',
#   'Lat': -33.963,
#   'Lng': 22.4617,
#   'Max Temp': 51.35,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'ZA',
#   'Date': 1635812669},
#  {'City': 'dawlatabad',
#   'Lat': 36.4141,
#   'Lng': 64.9053,
#   'Max Temp': 47.66,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 5.7,
#   'Country': 'AF',
#   'Date': 1635812669},
#  {'City': 'maragogi',
#   'Lat': -9.0122,
#   'Lng': -35.2225,
#   'Max Temp': 78.26,
#   'Humidity': 81,
#   'Cloudiness': 56,
#   'Wind Speed': 11.36,
#   'Country': 'BR',
#   'Date': 1635812483},
#  {'City': 'deniliquin',
#   'Lat': -35.5333,
#   'Lng': 144.9667,
#   'Max Temp': 80.01,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 13.2,
#   'Country': 'AU',
#   'Date': 1635812670},
#  {'City': 'noyabrsk',
#   'Lat': 63.1994,
#   'Lng': 75.4507,
#   'Max Temp': 2.16,
#   'Humidity': 96,
#   'Cloudiness': 80,
#   'Wind Speed': 11.79,
#   'Country': 'RU',
#   'Date': 1635812670},
#  {'City': 'talcahuano',
#   'Lat': -36.7167,
#   'Lng': -73.1167,
#   'Max Temp': 55.08,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'CL',
#   'Date': 1635812671},
#  {'City': 'santa maria',
#   'Lat': -29.6842,
#   'Lng': -53.8069,
#   'Max Temp': 72.7,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'BR',
#   'Date': 1635812671},
#  {'City': 'meghri',
#   'Lat': 38.9029,
#   'Lng': 46.2446,
#   'Max Temp': 59.76,
#   'Humidity': 63,
#   'Cloudiness': 98,
#   'Wind Speed': 4.72,
#   'Country': 'AM',
#   'Date': 1635812672},
#  {'City': 'verkhniy avzyan',
#   'Lat': 53.5289,
#   'Lng': 57.5372,
#   'Max Temp': 34.65,
#   'Humidity': 97,
#   'Cloudiness': 93,
#   'Wind Speed': 2.04,
#   'Country': 'RU',
#   'Date': 1635812672},
#  {'City': 'kiunga',
#   'Lat': -6.1219,
#   'Lng': 141.2906,
#   'Max Temp': 75.04,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 0.47,
#   'Country': 'PG',
#   'Date': 1635812673},
#  {'City': 'arkhara',
#   'Lat': 49.4212,
#   'Lng': 130.0842,
#   'Max Temp': 30.65,
#   'Humidity': 39,
#   'Cloudiness': 9,
#   'Wind Speed': 4.54,
#   'Country': 'RU',
#   'Date': 1635812673},
#  {'City': 'aripuana',
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp': 71.11,
#   'Humidity': 99,
#   'Cloudiness': 94,
#   'Wind Speed': 1.07,
#   'Country': 'BR',
#   'Date': 1635812663},
#  {'City': 'matamoros',
#   'Lat': 25.5333,
#   'Lng': -103.25,
#   'Max Temp': 83.1,
#   'Humidity': 27,
#   'Cloudiness': 21,
#   'Wind Speed': 9.73,
#   'Country': 'MX',
#   'Date': 1635812386},
#  {'City': 'ikryanoye',
#   'Lat': 46.0932,
#   'Lng': 47.7308,
#   'Max Temp': 44.58,
#   'Humidity': 54,
#   'Cloudiness': 94,
#   'Wind Speed': 10.45,
#   'Country': 'RU',
#   'Date': 1635812674},
#  {'City': 'pavilosta',
#   'Lat': 56.8879,
#   'Lng': 21.1859,
#   'Max Temp': 42.71,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'LV',
#   'Date': 1635812674},
#  {'City': 'mokokchung',
#   'Lat': 26.3333,
#   'Lng': 94.5333,
#   'Max Temp': 53.08,
#   'Humidity': 84,
#   'Cloudiness': 4,
#   'Wind Speed': 3.44,
#   'Country': 'IN',
#   'Date': 1635812675},
#  {'City': 'santa rosa',
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp': 82.38,
#   'Humidity': 79,
#   'Cloudiness': 82,
#   'Wind Speed': 12.39,
#   'Country': 'PH',
#   'Date': 1635812675},
#  {'City': 'harper',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 77.27,
#   'Humidity': 89,
#   'Cloudiness': 89,
#   'Wind Speed': 4.61,
#   'Country': 'LR',
#   'Date': 1635812676},
#  {'City': 'bowen',
#   'Lat': -20.0167,
#   'Lng': 148.2333,
#   'Max Temp': 80.82,
#   'Humidity': 59,
#   'Cloudiness': 67,
#   'Wind Speed': 19.26,
#   'Country': 'AU',
#   'Date': 1635812676},
#  {'City': 'eyl',
#   'Lat': 7.9803,
#   'Lng': 49.8164,
#   'Max Temp': 76.12,
#   'Humidity': 79,
#   'Cloudiness': 52,
#   'Wind Speed': 8.3,
#   'Country': 'SO',
#   'Date': 1635812677},
#  {'City': 'mantua',
#   'Lat': 45.1667,
#   'Lng': 10.7833,
#   'Max Temp': 53.71,
#   'Humidity': 90,
#   'Cloudiness': 98,
#   'Wind Speed': 5.99,
#   'Country': 'IT',
#   'Date': 1635812677},
#  {'City': 'nanning',
#   'Lat': 22.8167,
#   'Lng': 108.3167,
#   'Max Temp': 66.65,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.53,
#   'Country': 'CN',
#   'Date': 1635812677},
#  {'City': 'tianpeng',
#   'Lat': 30.9866,
#   'Lng': 103.9393,
#   'Max Temp': 57.67,
#   'Humidity': 89,
#   'Cloudiness': 94,
#   'Wind Speed': 1.83,
#   'Country': 'CN',
#   'Date': 1635812678},
#  {'City': 'vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 69.53,
#   'Humidity': 60,
#   'Cloudiness': 71,
#   'Wind Speed': 16.8,
#   'Country': 'NC',
#   'Date': 1635812678},
#  {'City': 'banjar',
#   'Lat': -8.19,
#   'Lng': 114.9675,
#   'Max Temp': 82.26,
#   'Humidity': 79,
#   'Cloudiness': 96,
#   'Wind Speed': 2.95,
#   'Country': 'ID',
#   'Date': 1635812679},
#  {'City': 'yerbogachen',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': 12.9,
#   'Humidity': 82,
#   'Cloudiness': 98,
#   'Wind Speed': 12.17,
#   'Country': 'RU',
#   'Date': 1635812679},
#  {'City': 'micheweni',
#   'Lat': -4.9667,
#   'Lng': 39.8333,
#   'Max Temp': 78.19,
#   'Humidity': 86,
#   'Cloudiness': 15,
#   'Wind Speed': 8.28,
#   'Country': 'TZ',
#   'Date': 1635812680},
#  {'City': 'gornopravdinsk',
#   'Lat': 60.05,
#   'Lng': 69.9,
#   'Max Temp': 7.59,
#   'Humidity': 94,
#   'Cloudiness': 33,
#   'Wind Speed': 5.95,
#   'Country': 'RU',
#   'Date': 1635812681},
#  {'City': 'leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 3.38,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 9.86,
#   'Country': 'RU',
#   'Date': 1635812681},
#  {'City': 'siwana',
#   'Lat': 25.6333,
#   'Lng': 72.4167,
#   'Max Temp': 71.83,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 2.26,
#   'Country': 'IN',
#   'Date': 1635812682},
#  {'City': 'tiarei',
#   'Lat': -17.5333,
#   'Lng': -149.3333,
#   'Max Temp': 82.42,
#   'Humidity': 83,
#   'Cloudiness': 45,
#   'Wind Speed': 13.31,
#   'Country': 'PF',
#   'Date': 1635812682},
#  {'City': 'victoria point',
#   'Lat': -27.5833,
#   'Lng': 153.3,
#   'Max Temp': 75.42,
#   'Humidity': 64,
#   'Cloudiness': 99,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Date': 1635812683},
#  {'City': 'caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 76.01,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 9.31,
#   'Country': 'BR',
#   'Date': 1635812683},
#  {'City': 'wolkersdorf',
#   'Lat': 48.3833,
#   'Lng': 16.5167,
#   'Max Temp': 52.02,
#   'Humidity': 89,
#   'Cloudiness': 96,
#   'Wind Speed': 3,
#   'Country': 'AT',
#   'Date': 1635812684},
#  {'City': 'pankovka',
#   'Lat': 58.5,
#   'Lng': 31.1999,
#   'Max Temp': 38.8,
#   'Humidity': 85,
#   'Cloudiness': 4,
#   'Wind Speed': 7.45,
#   'Country': 'RU',
#   'Date': 1635812684},
#  {'City': 'touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 79.7,
#   'Humidity': 75,
#   'Cloudiness': 96,
#   'Wind Speed': 12.68,
#   'Country': 'BR',
#   'Date': 1635812685},
#  {'City': 'dolores',
#   'Lat': -36.3132,
#   'Lng': -57.6792,
#   'Max Temp': 55.22,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 10.31,
#   'Country': 'AR',
#   'Date': 1635812657},
#  {'City': 'asyut',
#   'Lat': 27.181,
#   'Lng': 31.1837,
#   'Max Temp': 71.37,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 6.17,
#   'Country': 'EG',
#   'Date': 1635812616},
#  {'City': 'tripoli',
#   'Lat': 32.8752,
#   'Lng': 13.1875,
#   'Max Temp': 76.12,
#   'Humidity': 43,
#   'Cloudiness': 2,
#   'Wind Speed': 7.99,
#   'Country': 'LY',
#   'Date': 1635812686},
#  {'City': 'manggar',
#   'Lat': -2.8833,
#   'Lng': 108.2667,
#   'Max Temp': 79.02,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3.24,
#   'Country': 'ID',
#   'Date': 1635812686},
#  {'City': 'villafranca de los barros',
#   'Lat': 38.5614,
#   'Lng': -6.3381,
#   'Max Temp': 54.82,
#   'Humidity': 86,
#   'Cloudiness': 84,
#   'Wind Speed': 7.11,
#   'Country': 'ES',
#   'Date': 1635812686},
#  {'City': 'hrebinka',
#   'Lat': 50.1171,
#   'Lng': 32.4361,
#   'Max Temp': 43.29,
#   'Humidity': 91,
#   'Cloudiness': 94,
#   'Wind Speed': 6.8,
#   'Country': 'UA',
#   'Date': 1635812687},
#  {'City': 'novotroitskaya',
#   'Lat': 45.3267,
#   'Lng': 41.5253,
#   'Max Temp': 49.95,
#   'Humidity': 88,
#   'Cloudiness': 86,
#   'Wind Speed': 9.51,
#   'Country': 'RU',
#   'Date': 1635812687},
#  {'City': 'beira',
#   'Lat': -19.8436,
#   'Lng': 34.8389,
#   'Max Temp': 76.98,
#   'Humidity': 84,
#   'Cloudiness': 35,
#   'Wind Speed': 8.41,
#   'Country': 'MZ',
#   'Date': 1635812688},
#  {'City': 'merauke',
#   'Lat': -8.4667,
#   'Lng': 140.3333,
#   'Max Temp': 83.93,
#   'Humidity': 72,
#   'Cloudiness': 97,
#   'Wind Speed': 11.25,
#   'Country': 'ID',
#   'Date': 1635812688},
#  {'City': 'centralia',
#   'Lat': 46.7162,
#   'Lng': -122.9543,
#   'Max Temp': 52.3,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': 1635812688},
#  {'City': 'honiara',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp': 85.3,
#   'Humidity': 70,
#   'Cloudiness': 83,
#   'Wind Speed': 2.44,
#   'Country': 'SB',
#   'Date': 1635812689},
#  {'City': 'vazante',
#   'Lat': -17.9869,
#   'Lng': -46.9078,
#   'Max Temp': 71.4,
#   'Humidity': 83,
#   'Cloudiness': 59,
#   'Wind Speed': 1.97,
#   'Country': 'BR',
#   'Date': 1635812689},
#  {'City': 'inhambupe',
#   'Lat': -11.7844,
#   'Lng': -38.3531,
#   'Max Temp': 72.43,
#   'Humidity': 92,
#   'Cloudiness': 57,
#   'Wind Speed': 8.37,
#   'Country': 'BR',
#   'Date': 1635812690},
#  {'City': 'conceicao do araguaia',
#   'Lat': -8.2578,
#   'Lng': -49.2647,
#   'Max Temp': 73.78,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.36,
#   'Country': 'BR',
#   'Date': 1635812690},
#  {'City': 'linhares',
#   'Lat': -19.3911,
#   'Lng': -40.0722,
#   'Max Temp': 71.11,
#   'Humidity': 98,
#   'Cloudiness': 99,
#   'Wind Speed': 2.71,
#   'Country': 'BR',
#   'Date': 1635812691},
#  {'City': 'svetlyy',
#   'Lat': 54.675,
#   'Lng': 20.1347,
#   'Max Temp': 41.05,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'RU',
#   'Date': 1635812691},
#  {'City': 'katangli',
#   'Lat': 51.7102,
#   'Lng': 143.2326,
#   'Max Temp': 32.27,
#   'Humidity': 53,
#   'Cloudiness': 93,
#   'Wind Speed': 11.01,
#   'Country': 'RU',
#   'Date': 1635812691},
#  {'City': 'xinqing',
#   'Lat': 48.2333,
#   'Lng': 129.5,
#   'Max Temp': 32.36,
#   'Humidity': 40,
#   'Cloudiness': 4,
#   'Wind Speed': 1.81,
#   'Country': 'CN',
#   'Date': 1635812692},
#  {'City': 'monrovia',
#   'Lat': 6.3005,
#   'Lng': -10.7969,
#   'Max Temp': 76.77,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 6.64,
#   'Country': 'LR',
#   'Date': 1635812692},
#  {'City': 'botou',
#   'Lat': 38.0667,
#   'Lng': 116.5667,
#   'Max Temp': 49.33,
#   'Humidity': 69,
#   'Cloudiness': 89,
#   'Wind Speed': 6.55,
#   'Country': 'CN',
#   'Date': 1635812693},
#  {'City': 'san patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 76.84,
#   'Humidity': 63,
#   'Cloudiness': 46,
#   'Wind Speed': 10.13,
#   'Country': 'US',
#   'Date': 1635812693},
#  {'City': 'dabakala',
#   'Lat': 8.3667,
#   'Lng': -4.4333,
#   'Max Temp': 75.13,
#   'Humidity': 78,
#   'Cloudiness': 88,
#   'Wind Speed': 3.11,
#   'Country': 'CI',
#   'Date': 1635812693},
#  {'City': 'columbus',
#   'Lat': 39.9612,
#   'Lng': -82.9988,
#   'Max Temp': 49.32,
#   'Humidity': 58,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': 1635812427},
#  {'City': 'troitskoye',
#   'Lat': 52.9821,
#   'Lng': 84.6757,
#   'Max Temp': 36.77,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 15.35,
#   'Country': 'RU',
#   'Date': 1635812694},
#  {'City': 'mount pleasant',
#   'Lat': 32.7941,
#   'Lng': -79.8626,
#   'Max Temp': 62.01,
#   'Humidity': 90,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1635812694},
#  {'City': 'bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -12.08,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.29,
#   'Country': 'RU',
#   'Date': 1635812695},
#  {'City': 'changying',
#   'Lat': 52.8733,
#   'Lng': 123.3213,
#   'Max Temp': 28.54,
#   'Humidity': 50,
#   'Cloudiness': 84,
#   'Wind Speed': 4.54,
#   'Country': 'CN',
#   'Date': 1635812696},
#  {'City': 'pimentel',
#   'Lat': -6.8367,
#   'Lng': -79.9342,
#   'Max Temp': 64.04,
#   'Humidity': 83,
#   'Cloudiness': 64,
#   'Wind Speed': 12.62,
#   'Country': 'PE',
#   'Date': 1635812696},
#  {'City': 'liuhe',
#   'Lat': 42.2401,
#   'Lng': 125.7172,
#   'Max Temp': 37.65,
#   'Humidity': 87,
#   'Cloudiness': 67,
#   'Wind Speed': 1.83,
#   'Country': 'CN',
#   'Date': 1635812696},
#  {'City': 'matara',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 76.78,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 7.27,
#   'Country': 'LK',
#   'Date': 1635812697},
#  {'City': 'miranda de ebro',
#   'Lat': 42.6865,
#   'Lng': -2.947,
#   'Max Temp': 52.54,
#   'Humidity': 71,
#   'Cloudiness': 6,
#   'Wind Speed': 8.9,
#   'Country': 'ES',
#   'Date': 1635812697},
#  {'City': 'geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 63.01,
#   'Humidity': 59,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': 1635812698},
#  {'City': 'shaowu',
#   'Lat': 27.3409,
#   'Lng': 117.4831,
#   'Max Temp': 60.89,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.53,
#   'Country': 'CN',
#   'Date': 1635812698}]

# %%
df_data = pd.DataFrame(all_data)
df_data
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           cherskiy  68.7500  161.3000     -6.74        94         100
# 1              jambi  -1.6000  103.6167     75.88        94          89
# 2              owase  34.0667  136.2000     66.83        64         100
# 3       constitucion -35.3333  -72.4167     51.73        89          96
# 4               hilo  19.7297 -155.0900     83.93        60          20
# ..               ...      ...       ...       ...       ...         ...
# 555            liuhe  42.2401  125.7172     37.65        87          67
# 556           matara   5.9485   80.5353     76.78        92          99
# 557  miranda de ebro  42.6865   -2.9470     52.54        71           6
# 558        geraldton -28.7667  114.6000     63.01        59          90
# 559           shaowu  27.3409  117.4831     60.89        98         100
#
#      Wind Speed Country        Date
# 0          9.86      RU  1635812449
# 1          1.77      ID  1635812450
# 2          2.48      JP  1635812450
# 3          9.22      CL  1635812156
# 4          8.05      US  1635812451
# ..          ...     ...         ...
# 555        1.83      CN  1635812696
# 556        7.27      LK  1635812697
# 557        8.90      ES  1635812697
# 558        8.05      AU  1635812698
# 559        2.53      CN  1635812698
#
# [560 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
df_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  560.000000  560.000000  560.000000  560.000000  560.000000  560.000000
# mean    20.790701   19.001125   57.869696   74.842857   59.808929    7.749929
# std     33.328836   91.347440   22.308565   18.371449   36.904522    5.503021
# min    -54.800000 -179.166700  -14.600000   14.000000    0.000000    0.000000
# 25%     -6.908575  -58.848175   44.970000   65.000000   20.000000    3.420000
# 50%     27.996950   21.367050   64.240000   78.000000   75.000000    6.670000
# 75%     46.813650  102.334775   75.490000   89.000000   94.000000   10.882500
# max     78.218600  179.316700   93.180000  100.000000  100.000000   28.430000
#
#                Date
# count  5.600000e+02
# mean   1.635813e+09
# std    8.779307e+01
# min    1.635812e+09
# 25%    1.635812e+09
# 50%    1.635813e+09
# 75%    1.635813e+09
# max    1.635813e+09

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(df_data['Lat'],df_data['Max Temp'])

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(df_data['Lat'],df_data['Humidity'])

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(df_data['Lat'],df_data['Cloudiness'])

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(df_data['Lat'],df_data['Wind Speed'])

# %% [markdown]
# ## Linear Regression

# %%
data_north= df_data.loc[df_data['Lat']>= 0]
data_south= df_data.loc[df_data['Lat']< 0]

# %%
def Graph_Reg (x_values, y_values): 
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regression_values = x_values * slope + intercept
    plt.scatter(x_values,y_values)
    plt.plot (x_values,regression_values, 'r-')
    plt.show

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Graph_Reg (data_north ['Lat'], data_north ['Max Temp'])

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Graph_Reg(data_south ['Lat'], data_south ['Max Temp'])

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Graph_Reg(data_north['Humidity'], data_north ['Lat'])

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Graph_Reg(data_south['Humidity'], data_south ['Lat'])

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Graph_Reg(data_north['Cloudiness'], data_north['Lat'])

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Graph_Reg(data_south['Cloudiness'],data_south['Lat'])

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Graph_Reg(data_north['Lat'],data_north['Wind Speed'])

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Graph_Reg(data_south['Lat'], data_south['Wind Speed'])
